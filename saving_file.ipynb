# %%
import plotly
import plotly.express as px
import plotly.figure_factory as ff
import pandas as pd
import numpy as np
from plotly.express import data
import matplotlib.pyplot as plt
from matplotlib import style
from pathlib import Path
import logging

# %%
pp=pd.read_csv('Superstore1.csv')
pp1 = pp[(pp['Segment'] == 'Consumer')]
[['Order Date', 'Segment', 'State', 'City',
  'Category', 'Sales', 'Profit']]
pp1.head()
# Out:
#     no       order _id  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  NaN             NaN  08-11-2016  11-11-2016    Second Class    CG-12520
# 1  2.0  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 3  4.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4  5.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 5  6.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
#
#      Customer Name   Segment        Country             City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States        Henderson  ...       42420
# 1      Claire Gute  Consumer  United States        Henderson  ...       42420
# 3   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 4   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 5  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
#
#    Region       Product ID         Category Sub-Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 3   South  FUR-TA-10000577        Furniture       Tables
# 4   South  OFF-ST-10000760  Office Supplies      Storage
# 5    West  FUR-FU-10001487        Furniture  Furnishings
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.8600         7
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 3      0.45 -383.0310
# 4      0.20    2.5164
# 5      0.00   14.1694
#
# [5 rows x 21 columns]

# %%
bd=pd.DataFrame(pp1.groupby(['Category','State']).agg({'Sales':'mean'})).reset_index()
bd
# Out:
#        Category       State       Sales
# 0     Furniture     Alabama  807.724000
# 1     Furniture     Arizona  246.577182
# 2     Furniture    Arkansas  402.228333
# 3     Furniture  California  312.081143
# 4     Furniture    Colorado  195.735080
# ..          ...         ...         ...
# 126  Technology       Texas  330.666463
# 127  Technology        Utah  170.312000
# 128  Technology    Virginia  872.963889
# 129  Technology  Washington  590.816154
# 130  Technology   Wisconsin  631.435714
#
# [131 rows x 3 columns]

# %%
ofsp=bd[(bd['Category'] == 'Office Supplies')]
ofsp
# Out:
#            Category                 State       Sales
# 44  Office Supplies               Alabama  138.398462
# 45  Office Supplies               Arizona   66.726388
# 46  Office Supplies              Arkansas  169.131905
# 47  Office Supplies            California  113.697462
# 48  Office Supplies              Colorado   94.543260
# 49  Office Supplies           Connecticut   96.393056
# 50  Office Supplies              Delaware   76.296071
# 51  Office Supplies  District of Columbia   16.130000
# 52  Office Supplies               Florida   63.646047
# 53  Office Supplies               Georgia  217.275818
# 54  Office Supplies                 Idaho  130.353500
# 55  Office Supplies              Illinois   63.686981
# 56  Office Supplies               Indiana  120.420976
# 57  Office Supplies                  Iowa   35.808000
# 58  Office Supplies                Kansas   66.978333
# 59  Office Supplies              Kentucky  138.283256
# 60  Office Supplies             Louisiana  193.994000
# 61  Office Supplies              Maryland  180.661786
# 62  Office Supplies         Massachusetts  103.796053
# 63  Office Supplies              Michigan  294.731188
# 64  Office Supplies             Minnesota  364.259231
# 65  Office Supplies           Mississippi  122.569333
# 66  Office Supplies              Missouri   88.662308
# 67  Office Supplies               Montana  287.532000
# 68  Office Supplies              Nebraska   87.548333
# 69  Office Supplies                Nevada  167.745000
# 70  Office Supplies         New Hampshire  161.268000
# 71  Office Supplies            New Jersey  182.128824
# 72  Office Supplies            New Mexico   33.384500
# 73  Office Supplies              New York  125.494435
# 74  Office Supplies        North Carolina   86.302919
# 75  Office Supplies          North Dakota  178.306000
# 76  Office Supplies                  Ohio   62.141085
# 77  Office Supplies              Oklahoma  116.901579
# 78  Office Supplies                Oregon   62.141098
# 79  Office Supplies          Pennsylvania  127.191163
# 80  Office Supplies          Rhode Island   40.736000
# 81  Office Supplies        South Carolina  137.201250
# 82  Office Supplies          South Dakota   22.865000
# 83  Office Supplies             Tennessee  142.445271
# 84  Office Supplies                 Texas   89.952604
# 85  Office Supplies                  Utah  137.030273
# 86  Office Supplies               Vermont  159.295000
# 87  Office Supplies              Virginia   87.769714
# 88  Office Supplies            Washington  127.823735
# 89  Office Supplies             Wisconsin  160.863889

# %%
class FileError(Exception):
    '''Custom File Handling Error Exception'''

# %%
def save_file():
    fname = input("Enter the file name (with .png or .jpg extension): ").strip()
    logging.basicConfig(level=logging.INFO, 
                        filename="Graph.log", 
                        filemode="w",
                        format="%(asctime)s - %(levelname)s - %(message)s")
    if not fname.endswith(('.png','.jpg')):
        logging.warning('Issue with the provided extension, please check again!')
        raise ValueError("File name must end with .png or .jpg")
 
     
    plt.savefig(fname)
    print(f"Plot saved successfully as '{fname}'!")
    logging.info('Process Saved Successfully!')

try:
    plt.figure(figsize=(12, 6))
    x = ofsp['State']
    y = ofsp['Sales']
    plt.plot(x, y, label='Office Supplies', color='skyblue')
    plt.xticks(rotation=90)
    plt.xlabel('State')
    plt.ylabel('Sales')
    plt.title('Consumer Segment')
    plt.legend()
    
    save = input("Do you want to save the plot? (1.yes/2.no): ").strip()
    if save == '1':
        save_file()
    else:
        print("Plot not saved.")
        logging.error('Invalid Choice!')
        raise FileError("Invalid Option!")

    plt.show()
    
except FileError as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Plot saved successfully as 'state_sales.jpg'!
